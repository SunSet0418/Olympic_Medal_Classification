# %% [markdown]
# # Linear Regression

# %%
import csv
import tensorflow as tf

data_x = []
data_y = []

def read_data():
    dataset = []
    with open('dataset/athlete_events.csv', 'r', encoding='utf-8') as f:

        reader = csv.reader(f)

        for row in reader:
            json = {}

            if row[3] == 'NA' or row[4] == 'NA' or row[5] == 'NA' or row[14] == 'NA':
                pass

            else:
                json['age'] = row[3]
                json['height'] = row[4]
                json['weight'] = row[5]
                json['medal'] = row[14]
                dataset.append(json)

        del dataset[0]

    return dataset


def set_train_data():

    datas = read_data()

    for row in datas:
        tmp = []

        tmp.append(float(row['age']))
        tmp.append(float(row['height']))
        tmp.append(float(row['weight']))

        data_x.append(tmp)

        if row['medal'] == 'Gold':
            data_y.append([1])
        elif row['medal'] == 'Silver':
            data_y.append([2])
        elif row['medal'] == 'Bronze':
            data_y.append([3])
        else:
            data_y.append(row['medal'])

    print("data len : " + str(len(data_x)))
    
set_train_data()

train_x = tf.placeholder(tf.float32)
train_y = tf.placeholder(tf.float32)

weight = tf.Variable(tf.random_normal([1, 30181]))
bias = tf.Variable(tf.random_normal([1]))

hypothesis = tf.add(tf.matmul(weight, data_x), bias)

#cost = tf.reduce_mean(tf.square(hypothesis - train_y))
#cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=hypothesis, labels=train_y))
cost = tf.losses.mean_squared_error(labels=train_y, predictions=hypothesis)

learning_rate = 0.01

train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

saver = tf.train.Saver()

save_path = "./checkpoints/olympic_model.ckpt"

if __name__ == "__main__":
    
    with tf.Session() as sess:
        
        saver.restore(sess, save_path)
        result = sess.run([hypothesis], feed_dict={train_x : [[22.0, 185.0, 82.0]]})
# Out:
# data len : 30181
# INFO:tensorflow:Restoring parameters from ./checkpoints/olympic_model.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# NotFoundError: Key Variable_10 not found in checkpoint
# 	 [[Node: save_4/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_4/Const_0_0, save_4/RestoreV2/tensor_names, save_4/RestoreV2/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-5-1d12c19c8db0> in <module>()
#      79     with tf.Session() as sess:
#      80
# ---> 81         saver.restore(sess, save_path)
#      82         result = sess.run([hypothesis], feed_dict={train_x : [[22.0, 185.0, 82.0]]})
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1800     else:
#    1801       sess.run(self.saver_def.restore_op_name,
# -> 1802                {self.saver_def.filename_tensor_name: save_path})
#    1803
#    1804   @staticmethod
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# NotFoundError: Key Variable_10 not found in checkpoint
# 	 [[Node: save_4/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_4/Const_0_0, save_4/RestoreV2/tensor_names, save_4/RestoreV2/shape_and_slices)]]
#
# Caused by op 'save_4/RestoreV2', defined at:
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-1d12c19c8db0>", line 73, in <module>
#     saver = tf.train.Saver()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1338, in __init__
#     self.build()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1347, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1384, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 835, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 472, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 886, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1463, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Key Variable_10 not found in checkpoint
# 	 [[Node: save_4/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_4/Const_0_0, save_4/RestoreV2/tensor_names, save_4/RestoreV2/shape_and_slices)]]

# %% [markdown]
# # Neural Network

# %%
import csv
import tensorflow as tf
import numpy as np

data_x = []
data_y = []

train_x = tf.placeholder(tf.float32, shape=[None, 3])
train_y = tf.placeholder(tf.float32, shape=[None, 1])

def read_data():
    dataset = []
    with open('dataset/athlete_events.csv', 'r', encoding='utf-8') as f:

        reader = csv.reader(f)

        for row in reader:
            json = {}

            if row[3] == 'NA' or row[4] == 'NA' or row[5] == 'NA' or row[14] == 'NA':
                pass

            else:
                json['age'] = row[3]
                json['height'] = row[4]
                json['weight'] = row[5]
                json['medal'] = row[14]
                dataset.append(json)

        del dataset[0]

    return dataset


def set_train_data():
    datas = read_data()

    for row in datas:
        tmp = []

        tmp.append(float(row['age']))
        tmp.append(float(row['height']))
        tmp.append(float(row['weight']))

        data_x.append(tmp)

        if row['medal'] == 'Gold':
            data_y.append([1])
        elif row['medal'] == 'Silver':
            data_y.append([2])
        elif row['medal'] == 'Bronze':
            data_y.append([3])
        else:
            data_y.append(row['medal'])

    x_shape = np.array(data_x)
    y_shape = np.array(data_y)

#     print("data len : " + str(len(data_x)))

    print("data_X Shape : ", x_shape.shape)
    print("data_Y Shape : ", y_shape.shape)

# set_train_data()

w1 = tf.Variable(tf.random_normal([3, 32]))
b1 = tf.Variable(tf.random_normal([32]))
l1 = tf.nn.relu(tf.add(tf.matmul(train_x, w1), b1))

w2 = tf.Variable(tf.random_normal([32, 16]))
b2 = tf.Variable(tf.random_normal([16]))
l2 = tf.nn.relu(tf.add(tf.matmul(l1, w2), b2))

w3 = tf.Variable(tf.random_normal([16, 1]))
b3 = tf.Variable(tf.random_normal([1]))
hypothesis = tf.add(tf.matmul(l2, w3), b3)

cost = tf.losses.mean_squared_error(labels=train_y, predictions=hypothesis)

learning_rate = 0.01

train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

saver = tf.train.Saver()

save_path = "./checkpoints/olympic_nn_model.ckpt"

with tf.Session() as sess:
    
    saver.restore(sess, save_path)

    result = sess.run([hypothesis], feed_dict={train_x : [[22.0, 185.0, 82.0]]})
    
    print(result)
            
    print("Finished")
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoints/olympic_nn_model.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# NotFoundError: Key Variable_12 not found in checkpoint
# 	 [[Node: save_6/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_6/Const_0_0, save_6/RestoreV2/tensor_names, save_6/RestoreV2/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-7-d6d996e9323e> in <module>()
#      88 with tf.Session() as sess:
#      89
# ---> 90     saver.restore(sess, save_path)
#      91
#      92     result = sess.run([hypothesis], feed_dict={train_x : [[22.0, 185.0, 82.0]]})
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1800     else:
#    1801       sess.run(self.saver_def.restore_op_name,
# -> 1802                {self.saver_def.filename_tensor_name: save_path})
#    1803
#    1804   @staticmethod
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# NotFoundError: Key Variable_12 not found in checkpoint
# 	 [[Node: save_6/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_6/Const_0_0, save_6/RestoreV2/tensor_names, save_6/RestoreV2/shape_and_slices)]]
#
# Caused by op 'save_6/RestoreV2', defined at:
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-d6d996e9323e>", line 84, in <module>
#     saver = tf.train.Saver()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1338, in __init__
#     self.build()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1347, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1384, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 835, in _build_internal
#     restore_sequentially, reshape)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 472, in _AddRestoreOps
#     restore_sequentially)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 886, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1463, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# NotFoundError (see above for traceback): Key Variable_12 not found in checkpoint
# 	 [[Node: save_6/RestoreV2 = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_6/Const_0_0, save_6/RestoreV2/tensor_names, save_6/RestoreV2/shape_and_slices)]]
