# %% [markdown]
# # Training Model (Linear Regression)

# %%
import csv
import tensorflow as tf

data_x = []
data_y = []

def read_data():
    dataset = []
    with open('dataset/athlete_events.csv', 'r', encoding='utf-8') as f:

        reader = csv.reader(f)

        for row in reader:
            json = {}

            if row[3] == 'NA' or row[4] == 'NA' or row[5] == 'NA' or row[14] == 'NA':
                pass

            else:
                json['age'] = row[3]
                json['height'] = row[4]
                json['weight'] = row[5]
                json['medal'] = row[14]
                dataset.append(json)

        del dataset[0]

    return dataset


def set_train_data():

    datas = read_data()

    for row in datas:
        tmp = []

        tmp.append(float(row['age']))
        tmp.append(float(row['height']))
        tmp.append(float(row['weight']))

        data_x.append(tmp)

        if row['medal'] == 'Gold':
            data_y.append([1])
        elif row['medal'] == 'Silver':
            data_y.append([2])
        elif row['medal'] == 'Bronze':
            data_y.append([3])
        else:
            data_y.append(row['medal'])

    print("data len : " + str(len(data_x)))
    
set_train_data()

train_x = tf.placeholder(tf.float32)
train_y = tf.placeholder(tf.float32)

weight = tf.Variable(tf.random_normal([1, 30181]))
bias = tf.Variable(tf.random_normal([1]))

hypothesis = tf.add(tf.matmul(weight, data_x), bias)

#cost = tf.reduce_mean(tf.square(hypothesis - train_y))
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=hypothesis, labels=train_y))

learning_rate = 0.01

train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

saver = tf.train.Saver()

save_path = "./checkpoints/olympic_model.ckpt"

if __name__ == "__main__":
    
    with tf.Session() as sess:
        
        sess.run(tf.global_variables_initializer())

        for step in range(10001):

            cost_v, hyp_v, _ = sess.run([cost, hypothesis, train], feed_dict={train_x: data_x, train_y: data_y})
            if step % 100 == 0:
                print("STEP :",step, "Cost :", cost_v, "Hypothesis :",len(hyp_v))

        saver.save(sess, save_path)
# Out:
# data len : 30181
# STEP : 0 Cost : 90490.984 Hypothesis : 1
# STEP : 100 Cost : 15170676.0 Hypothesis : 1
# STEP : 200 Cost : 30576000.0 Hypothesis : 1
# STEP : 300 Cost : 46002860.0 Hypothesis : 1
# STEP : 400 Cost : 61438560.0 Hypothesis : 1
# STEP : 500 Cost : 76879096.0 Hypothesis : 1
# STEP : 600 Cost : 92322640.0 Hypothesis : 1
# STEP : 700 Cost : 107768270.0 Hypothesis : 1
# STEP : 800 Cost : 123215420.0 Hypothesis : 1
# STEP : 900 Cost : 138663680.0 Hypothesis : 1
# STEP : 1000 Cost : 154112850.0 Hypothesis : 1
# STEP : 1100 Cost : 169562700.0 Hypothesis : 1
# STEP : 1200 Cost : 185013070.0 Hypothesis : 1
# STEP : 1300 Cost : 200464130.0 Hypothesis : 1
# STEP : 1400 Cost : 215915520.0 Hypothesis : 1
# STEP : 1500 Cost : 231366940.0 Hypothesis : 1
# STEP : 1600 Cost : 246818510.0 Hypothesis : 1
# STEP : 1700 Cost : 262270100.0 Hypothesis : 1
# STEP : 1800 Cost : 277721630.0 Hypothesis : 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-61e0b8daff1f> in <module>()
#      82         for step in range(10001):
#      83
# ---> 84             cost_v, hyp_v, _ = sess.run([cost, hypothesis, train], feed_dict={train_x: data_x, train_y: data_y})
#      85             if step % 100 == 0:
#      86                 print("STEP :",step, "Cost :", cost_v, "Hypothesis :",len(hyp_v))
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1102             feed_handles[subfeed_t] = subfeed_val
#    1103           else:
# -> 1104             np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1105
#    1106           if (not is_tensor_handle_feed and
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# KeyboardInterrupt:

# %% [markdown]
# # Training Model (Neural Net)

# %%
import csv
import tensorflow as tf
import numpy as np

data_x = []
data_y = []

train_x = tf.placeholder(tf.float32)
train_y = tf.placeholder(tf.float32)

def read_data():
    dataset = []
    with open('dataset/athlete_events.csv', 'r', encoding='utf-8') as f:

        reader = csv.reader(f)

        for row in reader:
            json = {}

            if row[3] == 'NA' or row[4] == 'NA' or row[5] == 'NA' or row[14] == 'NA':
                pass

            else:
                json['age'] = row[3]
                json['height'] = row[4]
                json['weight'] = row[5]
                json['medal'] = row[14]
                dataset.append(json)

        del dataset[0]

    return dataset


def set_train_data():
    datas = read_data()

    for row in datas:
        tmp = []

        tmp.append(float(row['age']))
        tmp.append(float(row['height']))
        tmp.append(float(row['weight']))

        data_x.append(tmp)

        if row['medal'] == 'Gold':
            data_y.append([1])
        elif row['medal'] == 'Silver':
            data_y.append([2])
        elif row['medal'] == 'Bronze':
            data_y.append([3])
        else:
            data_y.append(row['medal'])

    x_shape = np.array(data_x)
    y_shape = np.array(data_y)

    print("data len : " + str(len(data_x)))

    print("data_X Shape : ", x_shape.shape)
    print("data_Y Shape : ", y_shape.shape)

set_train_data()

w1 = tf.Variable(tf.random_normal([3, 32]))
w2 = tf.Variable(tf.random_normal([32, 16]))
w3 = tf.Variable(tf.random_normal([16, 1]))

b1 = tf.Variable(tf.random_normal([32]))
b2 = tf.Variable(tf.random_normal([16]))
b3 = tf.Variable(tf.random_normal([1]))

l1 = tf.nn.relu(tf.add(tf.matmul(train_x, w1), b1))
l2 = tf.nn.relu(tf.add(tf.matmul(l1, w2), b2))
hypothesis = tf.add(tf.matmul(l2, w3), b3)

#cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=hypothesis, labels=train_y))
cost = tf.reduce_mean(tf.square(hypothesis - train_y))

learning_rate = 0.01

train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

saver = tf.train.Saver()

save_path = "./checkpoints/olympic_nn_model.ckpt"

with tf.Session() as sess:
    
    sess.run(tf.global_variables_initializer())

    print("Leaning Start!")

    for step in range(10001):

        cost_v, hyp_v, _ = sess.run([cost, hypothesis, train], feed_dict={train_x: data_x, train_y: data_y})
        if step % 100 == 0:
            print("STEP :",step, "Cost :", cost_v, "Hypothesis :",len(hyp_v))
        
    saver.save(sess, save_path)
            
    print("Finished")
# Out:
# data len : 30181
# data_X Shape :  (30181, 3)
# data_Y Shape :  (30181, 1)
# Leaning Start!
# STEP : 0 Cost : 138844.19 Hypothesis : 30181
# STEP : 100 Cost : 66.790115 Hypothesis : 30181
# STEP : 200 Cost : 35.442062 Hypothesis : 30181
