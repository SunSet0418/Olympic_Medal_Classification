# %% [markdown]
# # Training Model (Linear Regression)

# %%
import csv
import tensorflow as tf

data_x1 = []
data_x2 = []
data_x3 = []

data_y = []

train_x1 = tf.placeholder(tf.float32)
train_x2 = tf.placeholder(tf.float32)
train_x3 = tf.placeholder(tf.float32)

train_y = tf.placeholder(tf.float32)

w1 = tf.Variable(tf.random_normal([1]))
w2 = tf.Variable(tf.random_normal([1]))
w3 = tf.Variable(tf.random_normal([1]))

bias = tf.Variable(tf.random_normal([1]))

hypothesis = train_x1 * w1 + train_x2 * w2 + train_x3 * w3 + bias

cost = tf.reduce_mean(tf.square(hypothesis - train_y))

learning_rate = 0.01

train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

def read_data():
    dataset = []
    with open('dataset/athlete_events.csv', 'r', encoding='utf-8') as f:

        reader = csv.reader(f)

        for row in reader:
            json = {}

            if row[3] == 'NA' or row[4] == 'NA' or row[5] == 'NA' or row[14] == 'NA':
                pass

            else:
                json['age'] = row[3]
                json['height'] = row[4]
                json['weight'] = row[5]
                json['medal'] = row[14]
                dataset.append(json)

        del dataset[0]

    return dataset


def set_train_data():
    datas = read_data()

    for row in datas:
        data_x1.append([float(row['age'])])
        data_x2.append([float(row['height'])])
        data_x3.append([float(row['weight'])])
        if row['medal'] == 'Gold':
            data_y.append([1])
        elif row['medal'] == 'Silver':
            data_y.append([2])
        elif row['medal'] == 'Bronze':
            data_y.append([3])
        else:
            data_y.append(row['medal'])

    print("data len : "+str(len(data_x1)))

    # print(data_x1)
    # print(data_x2)
    # print(data_x3)
    # print(data_y)
saver = tf.train.Saver()

save_path = "./checkpoints/olympic_model.ckpt"

with tf.Session() as sess:

    set_train_data()

    sess.run(tf.global_variables_initializer())

    for step in range(10001):

        cost_v, hyp_v, _ = sess.run([cost, hypothesis, train], feed_dict={train_x1 : data_x1, train_x2 : data_x2, train_x3 : data_x3, train_y : data_y})
        
        if step % 100 == 0:

            print(step, "Cost : ", cost_v)
# Out:
# /home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# data len : 30181
# 0 Cost :  13104.268
# 100 Cost :  77.50497
# 200 Cost :  70.84319
# 300 Cost :  63.505432
# 400 Cost :  55.611553
# 500 Cost :  47.65896
# 600 Cost :  40.01391
# 700 Cost :  32.93585
# 800 Cost :  26.592089
# 900 Cost :  21.071266
# 1000 Cost :  16.397133
# 1100 Cost :  12.54292
# 1200 Cost :  9.445531
# 1300 Cost :  7.0187073
# 1400 Cost :  5.164655
# 1500 Cost :  3.7834797
# 1600 Cost :  2.780268
# 1700 Cost :  2.0698254
# 1800 Cost :  1.5792977
# 1900 Cost :  1.2490257
# 2000 Cost :  1.032085
# 2100 Cost :  0.8929533
# 2200 Cost :  0.80571526
# 2300 Cost :  0.7521301
# 2400 Cost :  0.7197981
# 2500 Cost :  0.70056796
# 2600 Cost :  0.6892484
# 2700 Cost :  0.6826271
# 2800 Cost :  0.6787654
# 2900 Cost :  0.6765156
# 3000 Cost :  0.6752064
# 3100 Cost :  0.6744474
# 3200 Cost :  0.6740107
# 3300 Cost :  0.67376256
# 3400 Cost :  0.6736238
# 3500 Cost :  0.67354786
# 3600 Cost :  0.673507
# 3700 Cost :  0.6734853
# 3800 Cost :  0.6734737
# 3900 Cost :  0.6734672
# 4000 Cost :  0.6734632
# 4100 Cost :  0.67346036
# 4200 Cost :  0.67345786
# 4300 Cost :  0.6734554
# 4400 Cost :  0.6734531
# 4500 Cost :  0.67345065
# 4600 Cost :  0.67344815
# 4700 Cost :  0.67344546
# 4800 Cost :  0.6734426
# 4900 Cost :  0.6734398
# 5000 Cost :  0.6734367
# 5100 Cost :  0.6734334
# 5200 Cost :  0.6734301
# 5300 Cost :  0.67342657
# 5400 Cost :  0.6734229
# 5500 Cost :  0.673419
# 5600 Cost :  0.67341495
# 5700 Cost :  0.67341065
# 5800 Cost :  0.67340624
# 5900 Cost :  0.67340165
# 6000 Cost :  0.67339677
# 6100 Cost :  0.6733917
# 6200 Cost :  0.67338634
# 6300 Cost :  0.6733809
# 6400 Cost :  0.67337507
# 6500 Cost :  0.673369
# 6600 Cost :  0.67336273
# 6700 Cost :  0.6733562
# 6800 Cost :  0.67334926
# 6900 Cost :  0.6733421
# 7000 Cost :  0.67333466
# 7100 Cost :  0.6733269
# 7200 Cost :  0.67331886
# 7300 Cost :  0.67331046
# 7400 Cost :  0.67330176
# 7500 Cost :  0.67329276
# 7600 Cost :  0.6732833
# 7700 Cost :  0.6732735
# 7800 Cost :  0.6732634
# 7900 Cost :  0.6732529
# 8000 Cost :  0.6732421
# 8100 Cost :  0.6732308
# 8200 Cost :  0.67321914
# 8300 Cost :  0.6732071
# 8400 Cost :  0.67319477
# 8500 Cost :  0.67318195
# 8600 Cost :  0.67316884
# 8700 Cost :  0.67315525
# 8800 Cost :  0.6731413
# 8900 Cost :  0.67312694
# 9000 Cost :  0.67311233
# 9100 Cost :  0.6730973
# 9200 Cost :  0.67308193
# 9300 Cost :  0.67306626
# 9400 Cost :  0.6730502
# 9500 Cost :  0.673034
# 9600 Cost :  0.67301744
# 9700 Cost :  0.67300063
# 9800 Cost :  0.6729835
# 9900 Cost :  0.6729664
# 10000 Cost :  0.6729491

# %% [markdown]
# # Training Model (Neural Net)

# %%
import csv
import tensorflow as tf

data_x1 = []
data_x2 = []
data_x3 = []

data_y = []

train_x1 = tf.placeholder(tf.float32)
train_x2 = tf.placeholder(tf.float32)
train_x3 = tf.placeholder(tf.float32)

train_y = tf.placeholder(tf.float32)

w1 = tf.Variable(tf.random_normal([1, 15000]))
w2 = tf.Variable(tf.random_normal([15000, 15000]))
w3 = tf.Variable(tf.random_normal([15000, 3]))

b1 = tf.Variable(tf.random_normal([15000]))
b2 = tf.Variable(tf.random_normal([15000]))
b3 = tf.Variable(tf.random_normal([3]))

l1 = tf.nn.relu(tf.add(tf.matmul(train_x1, w1), b1))
l2 = tf.nn.relu(tf.add(tf.matmul(l1, w2), b2))
hypothesis = tf.add(tf.matmul(l2, w3), b3)

cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=hypothesis, labels=train_y))

learning_rate = 0.01

train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

def read_data():
    dataset = []
    with open('dataset/athlete_events.csv', 'r', encoding='utf-8') as f:

        reader = csv.reader(f)

        for row in reader:
            json = {}

            if row[3] == 'NA' or row[4] == 'NA' or row[5] == 'NA' or row[14] == 'NA':
                pass

            else:
                json['age'] = row[3]
                json['height'] = row[4]
                json['weight'] = row[5]
                json['medal'] = row[14]
                dataset.append(json)

        del dataset[0]

    return dataset


def set_train_data():
    datas = read_data()

    for row in datas:
        data_x1.append([float(row['age'])])
        data_x2.append([float(row['height'])])
        data_x3.append([float(row['weight'])])
        if row['medal'] == 'Gold':
            data_y.append([1])
        elif row['medal'] == 'Silver':
            data_y.append([2])
        elif row['medal'] == 'Bronze':
            data_y.append([3])
        else:
            data_y.append(row['medal'])

    print("data len : "+str(len(data_x1)))

    # print(data_x1)
    # print(data_x2)
    # print(data_x3)
    # print(data_y)


with tf.Session() as sess:

    set_train_data()

    sess.run(tf.global_variables_initializer())

    for step in range(10001):
        print("Leaning Start!")

        cost_v, hyp_v, _ = sess.run([cost, hypothesis, train], feed_dict={train_x1 : data_x1, train_x2 : data_x2, train_x3 : data_x3, train_y : data_y})

        print(step, "Cost : ", cost_v)
# Out:
# /home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-1-fe61940fcc5c>:28: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# data len : 30181
# Leaning Start!
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[30181,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](_arg_Placeholder_0_0/_1, Variable/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[Node: Add_2/_7 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_250_Add_2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-1-fe61940fcc5c> in <module>()
#      89         print("Leaning Start!")
#      90
# ---> 91         cost_v, hyp_v, _ = sess.run([cost, hypothesis, train], feed_dict={train_x1 : data_x1, train_x2 : data_x2, train_x3 : data_x3, train_y : data_y})
#      92
#      93         print(step, "Cost : ", cost_v)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[30181,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](_arg_Placeholder_0_0/_1, Variable/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[Node: Add_2/_7 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_250_Add_2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'MatMul', defined at:
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-fe61940fcc5c>", line 24, in <module>
#     l1 = tf.nn.relu(tf.add(tf.matmul(train_x1, w1), b1))
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py", line 2122, in matmul
#     a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py", line 4279, in mat_mul
#     name=name)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "/home/sunset/.pyenv/versions/anaconda3-5.0.1/envs/ml/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[30181,15000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: MatMul = MatMul[T=DT_FLOAT, transpose_a=false, transpose_b=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"](_arg_Placeholder_0_0/_1, Variable/read)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[Node: Add_2/_7 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_250_Add_2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
